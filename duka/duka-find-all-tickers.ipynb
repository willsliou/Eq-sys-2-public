# %%
import requests
# import nasdaqdatalink as ns
import seaborn as sns
import yfinance as yf
import pandas as pd
from sqlalchemy import create_engine, inspect, text
from datetime import timedelta
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from bs4 import BeautifulSoup
import datetime
import signal
import time
import subprocess # CLI script
import os

# %%
# duka_us = pd.read_html(url)[0]
# duka_us

# %%
# if-exists accepts:
# "fail" (default): raise a ValueError exception if the table already exists.
# "replace": drop the existing table and create a new one with the same name and schema as the DataFrame.
# "append": add the data from the DataFrame to the existing table.

# %%
# engine = create_engine('sqlite:///Duka-Intraday_DB.db')
# # Add default main overlooking table to Duka-Intraday_DB
# try:
#     duka_us.to_sql("Main" ,engine, if_exists='fail')
# except Exception as e:
#     print("Table already exists. Error: ", e)

# %%
# Grab urls from text file
destination = 'C:/Users/hello/Documents/GitHub/eq-sys-1/duka/duka-url.txt'
with open(destination, 'r') as file:
    # Read the file line by line and store in a list
    list_urls = [line.strip() for line in file]

print([i for i in list_urls])
# Out:
# ['https://www.dukascopy-node.app/instruments/fx_crosses', 'https://www.dukascopy-node.app/instruments/fx_majors', 'https://www.dukascopy-node.app/instruments/fx_metals', 'https://www.dukascopy-node.app/instruments/cmd_agricultural', 'https://www.dukascopy-node.app/instruments/cmd_energy', 'https://www.dukascopy-node.app/instruments/cmd_metals', 'https://www.dukascopy-node.app/instruments/idx_america', 'https://www.dukascopy-node.app/instruments/idx_asia', 'https://www.dukascopy-node.app/instruments/idx_europe', 'https://www.dukascopy-node.app/instruments/idx_africa', 'https://www.dukascopy-node.app/instruments/austria', 'https://www.dukascopy-node.app/instruments/belgium', 'https://www.dukascopy-node.app/instruments/denmark', 'https://www.dukascopy-node.app/instruments/finland', 'https://www.dukascopy-node.app/instruments/france', 'https://www.dukascopy-node.app/instruments/germany', 'https://www.dukascopy-node.app/instruments/hong-kong', 'https://www.dukascopy-node.app/instruments/ireland', 'https://www.dukascopy-node.app/instruments/italy', 'https://www.dukascopy-node.app/instruments/japan', 'https://www.dukascopy-node.app/instruments/mexico', 'https://www.dukascopy-node.app/instruments/netherlands', 'https://www.dukascopy-node.app/instruments/norway', 'https://www.dukascopy-node.app/instruments/portugal', 'https://www.dukascopy-node.app/instruments/spain', 'https://www.dukascopy-node.app/instruments/sweden', 'https://www.dukascopy-node.app/instruments/switzerland', 'https://www.dukascopy-node.app/instruments/uk', 'https://www.dukascopy-node.app/instruments/us', 'https://www.dukascopy-node.app/instruments/bnd_cfd', 'https://www.dukascopy-node.app/instruments/etf_cfd_de', 'https://www.dukascopy-node.app/instruments/etf_cfd_fr', 'https://www.dukascopy-node.app/instruments/etf_cfd_hk', 'https://www.dukascopy-node.app/instruments/etf_cfd_us']

# %%
# Link -> id -> npm {symbol} -> execute
# symbol = str(pd.read_html(list_urls[0])[0]['id'])
# cmd_ = f'npx dukascopy-node -i {symbol} -from 1980-06-01 -to 2023-04-09 -t m1'
# print(cmd_)

# %%
# url = list_urls[0]
# a = pd.read_html(url)
# b = a[0]['id']
# for id in b:
#     print(id)

# %%
# npx_path = r'"C:\Program Files\nodejs\npx.cmd"'
# node_path = r'"C:\Program Files\nodejs"'

# %%
def fileExists(s1, s2):
    if s1 == s2:
        print("fileExists(): File exists.")
        return True

# %%
def createDB(ticker,df):
    print("Creating new table")
    engine = create_engine(f'sqlite:///{ticker}_Intraday.db')

    # Add default main overlooking table to ticker_Intraday_DB.db
    try:
        df.to_sql(ticker , engine, if_exists='append')
    except Exception as e:
        print("Table error: ", e)

# %%
import os
import subprocess
import time
import pandas as pd

npx_path = r'"C:\Program Files\nodejs\npx.cmd"'
node_path = r'"C:\Program Files\nodejs"'

# Update the PATH environment variable
os.environ["PATH"] += os.pathsep + node_path

def file_exists(directory, symbol):
    """
    Check if a file exists in the given directory with the given symbol name.
    """
    for local_file_name in os.listdir(directory):
        if local_file_name.endswith('.json'):
            # Get id
            ticker = local_file_name.split("-")[0]

            # Compare ids
#             print(f"Comparing {ticker} | {symbol}")
            if ticker == symbol:
                print(f"Match found in directory: {ticker} == {symbol}")
                return True
    return False

def run_subprocess(cmd, symbol):
    """
    Run the given subprocess command and print the output.
    """
    try:
        # Set the PATH environment variable for the subprocess
        env = os.environ.copy()
        print(f'Executing on {symbol}')
        process = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, env=env)
        stdout, stderr = process.communicate()
        print(stdout)

        if process.returncode != 0:
            raise subprocess.CalledProcessError(process.returncode, cmd, output=stdout, stderr=stderr)
    except subprocess.CalledProcessError as e:
        print(f"Error while processing {symbol}: {str(e)}")
        print("Output:", e.output)
        print("Error output:", e.stderr)

def sleep(interval):
    """
    Sleep for the given interval in seconds and print a message.
    """
    print(f"Sleeping for {interval} seconds...")
    time.sleep(interval)
    print("Resuming...")

symb_list = []
def periodic_work(interval, list_urls, symb_list):
    while True:
        print("Starting...")
        for url in list_urls:
            print(f"Reading from: {url}, with id: {pd.read_html(url)[0]['id']}")
            table_id = pd.read_html(url)[0]['id']
            for symbol in table_id:
                if symbol not in symb_list:
                    print(f"{symbol} not in list. Adding to list...")
                    symb_list.append(symbol)
                    
                else:
                    continue
#                 cmd = f'{npx_path} dukascopy-node -i {symbol} -from 1980-06-01 -to 2023-04-09 -t m1 -bs 15 -bp 2000'

#                 print("Checking if file exists...")
#                 directory = 'C:/Users/hello/Documents/GitHub/eq-sys-1/download'
#                 if file_exists(directory, symbol):
#                     print("Table already exists. Checking for new data...")
#                 else:
#                     print("Pull data")
#                     run_subprocess(cmd, symbol)

#                 sleep(interval)

# %%
interval = 1
periodic_work(interval, list_urls, symb_list)
# Out:
# Starting...
# Reading from: https://www.dukascopy-node.app/instruments/fx_crosses, with id: 0     audcad
# 1     audchf
# 2     audjpy
# 3     audnzd
# 4     audsgd
# 5     cadchf
# 6     cadhkd
# 7     cadjpy
# 8     chfjpy
# 9     chfsgd
# 10    euraud
# 11    eurcad
# 12    eurchf
# 13    eurczk
# 14    eurdkk
# 15    eurgbp
# 16    eurhkd
# 17    eurhuf
# 18    eurjpy
# 19    eurnok
# 20    eurnzd
# 21    eurpln
# 22    eursek
# 23    eursgd
# 24    eurtry
# 25    gbpaud
# 26    gbpcad
# 27    gbpchf
# 28    gbpjpy
# 29    gbpnzd
# 30    hkdjpy
# 31    nzdcad
# 32    nzdchf
# 33    nzdjpy
# 34    sgdjpy
# 35    tryjpy
# 36    usdcnh
# 37    usdczk
# 38    usddkk
# 39    usdhkd
# 40    usdhuf
# 41    usdils
# 42    usdmxn
# 43    usdnok
# 44    usdpln
# 45    usdron
# 46    usdsek
# 47    usdsgd
# 48    usdthb
# 49    usdtry
# 50    usdzar
# 51    zarjpy
# Name: id, dtype: object
# audcad not in list. Adding to list...
# audchf not in list. Adding to list...
# audjpy not in list. Adding to list...
# audnzd not in list. Adding to list...
# audsgd not in list. Adding to list...
# cadchf not in list. Adding to list...
# cadhkd not in list. Adding to list...
# cadjpy not in list. Adding to list...
# chfjpy not in list. Adding to list...
# chfsgd not in list. Adding to list...
# euraud not in list. Adding to list...
# eurcad not in list. Adding to list...
# eurchf not in list. Adding to list...
# eurczk not in list. Adding to list...
# eurdkk not in list. Adding to list...
# eurgbp not in list. Adding to list...
# eurhkd not in list. Adding to list...
# eurhuf not in list. Adding to list...
# eurjpy not in list. Adding to list...
# eurnok not in list. Adding to list...
# eurnzd not in list. Adding to list...
# eurpln not in list. Adding to list...
# eursek not in list. Adding to list...
# eursgd not in list. Adding to list...
# eurtry not in list. Adding to list...
# gbpaud not in list. Adding to list...
# gbpcad not in list. Adding to list...
# gbpchf not in list. Adding to list...
# gbpjpy not in list. Adding to list...
# gbpnzd not in list. Adding to list...
# hkdjpy not in list. Adding to list...
# nzdcad not in list. Adding to list...
# nzdchf not in list. Adding to list...
# nzdjpy not in list. Adding to list...
# sgdjpy not in list. Adding to list...
# tryjpy not in list. Adding to list...
# usdcnh not in list. Adding to list...
# usdczk not in list. Adding to list...
# usddkk not in list. Adding to list...
# usdhkd not in list. Adding to list...
# usdhuf not in list. Adding to list...
# usdils not in list. Adding to list...
# usdmxn not in list. Adding to list...
# usdnok not in list. Adding to list...
# usdpln not in list. Adding to list...
# usdron not in list. Adding to list...
# usdsek not in list. Adding to list...
# usdsgd not in list. Adding to list...
# usdthb not in list. Adding to list...
# usdtry not in list. Adding to list...
# usdzar not in list. Adding to list...
# zarjpy not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/fx_majors, with id: 0    audusd
# 1    eurusd
# 2    gbpusd
# 3    nzdusd
# 4    usdcad
# 5    usdchf
# 6    usdjpy
# Name: id, dtype: object
# audusd not in list. Adding to list...
# eurusd not in list. Adding to list...
# gbpusd not in list. Adding to list...
# nzdusd not in list. Adding to list...
# usdcad not in list. Adding to list...
# usdchf not in list. Adding to list...
# usdjpy not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/fx_metals, with id: 0    xagusd
# 1    xauusd
# Name: id, dtype: object
# xagusd not in list. Adding to list...
# xauusd not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/cmd_agricultural, with id: 0      cocoacmdusd
# 1     coffeecmdusx
# 2     cottoncmdusx
# 3     ojuicecmdusx
# 4    soybeancmdusx
# 5      sugarcmdusd
# Name: id, dtype: object
# cocoacmdusd not in list. Adding to list...
# coffeecmdusx not in list. Adding to list...
# cottoncmdusx not in list. Adding to list...
# ojuicecmdusx not in list. Adding to list...
# soybeancmdusx not in list. Adding to list...
# sugarcmdusd not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/cmd_energy, with id: 0    dieselcmdusd
# 1     brentcmdusd
# 2     lightcmdusd
# 3       gascmdusd
# Name: id, dtype: object
# dieselcmdusd not in list. Adding to list...
# brentcmdusd not in list. Adding to list...
# lightcmdusd not in list. Adding to list...
# gascmdusd not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/cmd_metals, with id: 0    coppercmdusd
# 1       xpdcmdusd
# 2       xptcmdusd
# Name: id, dtype: object
# coppercmdusd not in list. Adding to list...
# xpdcmdusd not in list. Adding to list...
# xptcmdusd not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/idx_america, with id: 0      dollaridxusd
# 1       usa30idxusd
# 2     usatechidxusd
# 3      usa500idxusd
# 4    ussc2000idxusd
# 5         volidxusd
# Name: id, dtype: object
# dollaridxusd not in list. Adding to list...
# usa30idxusd not in list. Adding to list...
# usatechidxusd not in list. Adding to list...
# usa500idxusd not in list. Adding to list...
# ussc2000idxusd not in list. Adding to list...
# volidxusd not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/idx_asia, with id: 0    chiidxusd
# 1    hkgidxhkd
# 2    jpnidxjpy
# 3    ausidxaud
# 4    indidxusd
# 5    sgdidxsgd
# Name: id, dtype: object
# chiidxusd not in list. Adding to list...
# hkgidxhkd not in list. Adding to list...
# jpnidxjpy not in list. Adding to list...
# ausidxaud not in list. Adding to list...
# indidxusd not in list. Adding to list...
# sgdidxsgd not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/idx_europe, with id: 0    fraidxeur
# 1    deuidxeur
# 2    eusidxeur
# 3    gbridxgbp
# 4    espidxeur
# 5    cheidxchf
# 6    nldidxeur
# 7    plnidxpln
# Name: id, dtype: object
# fraidxeur not in list. Adding to list...
# deuidxeur not in list. Adding to list...
# eusidxeur not in list. Adding to list...
# gbridxgbp not in list. Adding to list...
# espidxeur not in list. Adding to list...
# cheidxchf not in list. Adding to list...
# nldidxeur not in list. Adding to list...
# plnidxpln not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/idx_africa, with id: 0    soaidxzar
# Name: id, dtype: object
# soaidxzar not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/austria, with id: 0    ebsateur
# 1    rbiateur
# 2    voeateur
# Name: id, dtype: object
# ebsateur not in list. Adding to list...
# rbiateur not in list. Adding to list...
# voeateur not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/belgium, with id: 0     abibeeur
# 1     agsbeeur
# 2    belgbeeur
# 3     kbcbeeur
# 4    solbbeeur
# 5     ucbbeeur
# 6     umibeeur
# Name: id, dtype: object
# abibeeur not in list. Adding to list...
# agsbeeur not in list. Adding to list...
# belgbeeur not in list. Adding to list...
# kbcbeeur not in list. Adding to list...
# solbbeeur not in list. Adding to list...
# ucbbeeur not in list. Adding to list...
# umibeeur not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/denmark, with id: 0      carlbdkdkk
# 1      colobdkdkk
# 2     danskedkdkk
# 3    maerskbdkdkk
# 4      novobdkdkk
# 5      nzymbdkdkk
# 6     pndoradkdkk
# 7        vwsdkdkk
# Name: id, dtype: object
# carlbdkdkk not in list. Adding to list...
# colobdkdkk not in list. Adding to list...
# danskedkdkk not in list. Adding to list...
# maerskbdkdkk not in list. Adding to list...
# novobdkdkk not in list. Adding to list...
# nzymbdkdkk not in list. Adding to list...
# pndoradkdkk not in list. Adding to list...
# vwsdkdkk not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/finland, with id: 0    eli1vfieur
# 1    nes1vfieur
# 2    nre1vfieur
# 3    ote1vfieur
# 4    out1vfieur
# 5    stervfieur
# 6    tls1vfieur
# Name: id, dtype: object
# eli1vfieur not in list. Adding to list...
# nes1vfieur not in list. Adding to list...
# nre1vfieur not in list. Adding to list...
# ote1vfieur not in list. Adding to list...
# out1vfieur not in list. Adding to list...
# stervfieur not in list. Adding to list...
# tls1vfieur not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/france, with id: 0       acfreur
# 1      acafreur
# 2       affreur
# 3       aifreur
# 4      airfreur
# 5      alofreur
# 6      atofreur
# 7       bnfreur
# 8      bnpfreur
# 9       cafreur
# 10     capfreur
# 11      csfreur
# 12      dgfreur
# 13     dsyfreur
# 14     edffreur
# 15      enfreur
# 16    engifreur
# 17      fpfreur
# 18      frfreur
# 19     glefreur
# 20      hofreur
# 21     kerfreur
# 22      lifreur
# 23      lrfreur
# 24      mcfreur
# 25      mlfreur
# 26      orfreur
# 27     orafreur
# 28     pubfreur
# 29      rifreur
# 30     rmsfreur
# 31     rnofreur
# 32     saffreur
# 33     sanfreur
# 34     sgofreur
# 35      sufreur
# 36      swfreur
# 37      ugfreur
# 38     viefreur
# 39     vivfreur
# 40      vkfreur
# Name: id, dtype: object
# acfreur not in list. Adding to list...
# acafreur not in list. Adding to list...
# affreur not in list. Adding to list...
# aifreur not in list. Adding to list...
# airfreur not in list. Adding to list...
# alofreur not in list. Adding to list...
# atofreur not in list. Adding to list...
# bnfreur not in list. Adding to list...
# bnpfreur not in list. Adding to list...
# cafreur not in list. Adding to list...
# capfreur not in list. Adding to list...
# csfreur not in list. Adding to list...
# dgfreur not in list. Adding to list...
# dsyfreur not in list. Adding to list...
# edffreur not in list. Adding to list...
# enfreur not in list. Adding to list...
# engifreur not in list. Adding to list...
# fpfreur not in list. Adding to list...
# frfreur not in list. Adding to list...
# glefreur not in list. Adding to list...
# hofreur not in list. Adding to list...
# kerfreur not in list. Adding to list...
# lifreur not in list. Adding to list...
# lrfreur not in list. Adding to list...
# mcfreur not in list. Adding to list...
# mlfreur not in list. Adding to list...
# orfreur not in list. Adding to list...
# orafreur not in list. Adding to list...
# pubfreur not in list. Adding to list...
# rifreur not in list. Adding to list...
# rmsfreur not in list. Adding to list...
# rnofreur not in list. Adding to list...
# saffreur not in list. Adding to list...
# sanfreur not in list. Adding to list...
# sgofreur not in list. Adding to list...
# sufreur not in list. Adding to list...
# swfreur not in list. Adding to list...
# ugfreur not in list. Adding to list...
# viefreur not in list. Adding to list...
# vivfreur not in list. Adding to list...
# vkfreur not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/germany, with id: 0      adsdeeur
# 1      alvdeeur
# 2      basdeeur
# 3     bayndeeur
# 4      beideeur
# 5      bmwdeeur
# 6      bnrdeeur
# 7     bossdeeur
# 8      cbkdeeur
# 9      condeeur
# 10     covdeeur
# 11     daideeur
# 12     db1deeur
# 13     dbkdeeur
# 14     dhrdeeur
# 15     dpwdeeur
# 16     dtedeeur
# 17    eoandeeur
# 18     fmedeeur
# 19     fredeeur
# 20     heideeur
# 21    hen3deeur
# 22     hfgdeeur
# 23     hnrdeeur
# 24     ifxdeeur
# 25     lhadeeur
# 26     lindeeur
# 27     lxsdeeur
# 28     mrkdeeur
# 29     mtxdeeur
# 30    muv2deeur
# 31    pah3deeur
# 32     psmdeeur
# 33     pumdeeur
# 34     rwedeeur
# 35     sapdeeur
# 36     sdfdeeur
# 37     siedeeur
# 38     srtdeeur
# 39     sy1deeur
# 40     tkadeeur
# 41    tui1deeur
# 42     vnadeeur
# 43    vow3deeur
# Name: id, dtype: object
# adsdeeur not in list. Adding to list...
# alvdeeur not in list. Adding to list...
# basdeeur not in list. Adding to list...
# bayndeeur not in list. Adding to list...
# beideeur not in list. Adding to list...
# bmwdeeur not in list. Adding to list...
# bnrdeeur not in list. Adding to list...
# bossdeeur not in list. Adding to list...
# cbkdeeur not in list. Adding to list...
# condeeur not in list. Adding to list...
# covdeeur not in list. Adding to list...
# daideeur not in list. Adding to list...
# db1deeur not in list. Adding to list...
# dbkdeeur not in list. Adding to list...
# dhrdeeur not in list. Adding to list...
# dpwdeeur not in list. Adding to list...
# dtedeeur not in list. Adding to list...
# eoandeeur not in list. Adding to list...
# fmedeeur not in list. Adding to list...
# fredeeur not in list. Adding to list...
# heideeur not in list. Adding to list...
# hen3deeur not in list. Adding to list...
# hfgdeeur not in list. Adding to list...
# hnrdeeur not in list. Adding to list...
# ifxdeeur not in list. Adding to list...
# lhadeeur not in list. Adding to list...
# lindeeur not in list. Adding to list...
# lxsdeeur not in list. Adding to list...
# mrkdeeur not in list. Adding to list...
# mtxdeeur not in list. Adding to list...
# muv2deeur not in list. Adding to list...
# pah3deeur not in list. Adding to list...
# psmdeeur not in list. Adding to list...
# pumdeeur not in list. Adding to list...
# rwedeeur not in list. Adding to list...
# sapdeeur not in list. Adding to list...
# sdfdeeur not in list. Adding to list...
# siedeeur not in list. Adding to list...
# srtdeeur not in list. Adding to list...
# sy1deeur not in list. Adding to list...
# tkadeeur not in list. Adding to list...
# tui1deeur not in list. Adding to list...
# vnadeeur not in list. Adding to list...
# vow3deeur not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/hong-kong, with id: 0     0005hkhkd
# 1     0027hkhkd
# 2     0175hkhkd
# 3     0291hkhkd
# 4     0386hkhkd
# 5     0388hkhkd
# 6     0700hkhkd
# 7     0857hkhkd
# 8     0883hkhkd
# 9     0939hkhkd
# 10    0941hkhkd
# 11    0998hkhkd
# 12    1093hkhkd
# 13    1177hkhkd
# 14    1288hkhkd
# 15    1299hkhkd
# 16    1398hkhkd
# 17    1810hkhkd
# 18    1918hkhkd
# 19    2007hkhkd
# 20    2018hkhkd
# 21    2318hkhkd
# 22    2388hkhkd
# 23    2628hkhkd
# 24    3333hkhkd
# 25    3968hkhkd
# 26    3988hkhkd
# Name: id, dtype: object
# 0005hkhkd not in list. Adding to list...
# 0027hkhkd not in list. Adding to list...
# 0175hkhkd not in list. Adding to list...
# 0291hkhkd not in list. Adding to list...
# 0386hkhkd not in list. Adding to list...
# 0388hkhkd not in list. Adding to list...
# 0700hkhkd not in list. Adding to list...
# 0857hkhkd not in list. Adding to list...
# 0883hkhkd not in list. Adding to list...
# 0939hkhkd not in list. Adding to list...
# 0941hkhkd not in list. Adding to list...
# 0998hkhkd not in list. Adding to list...
# 1093hkhkd not in list. Adding to list...
# 1177hkhkd not in list. Adding to list...
# 1288hkhkd not in list. Adding to list...
# 1299hkhkd not in list. Adding to list...
# 1398hkhkd not in list. Adding to list...
# 1810hkhkd not in list. Adding to list...
# 1918hkhkd not in list. Adding to list...
# 2007hkhkd not in list. Adding to list...
# 2018hkhkd not in list. Adding to list...
# 2318hkhkd not in list. Adding to list...
# 2388hkhkd not in list. Adding to list...
# 2628hkhkd not in list. Adding to list...
# 3333hkhkd not in list. Adding to list...
# 3968hkhkd not in list. Adding to list...
# 3988hkhkd not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/ireland, with id: 0    birgieeur
# 1     crgieeur
# 2     krxieeur
# 3     krzieeur
# 4    ry4cieeur
# Name: id, dtype: object
# birgieeur not in list. Adding to list...
# crgieeur not in list. Adding to list...
# krxieeur not in list. Adding to list...
# krzieeur not in list. Adding to list...
# ry4cieeur not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/italy, with id: 0      a2aiteur
# 1      agliteur
# 2      ampiteur
# 3      atliteur
# 4      azmiteur
# 5     bamiiteur
# 6       bciteur
# 7     bmpsiteur
# 8      bpeiteur
# 9      breiteur
# 10     bzuiteur
# 11    cassiteur
# 12    cerviteur
# 13     cpriteur
# 14    cvaliteur
# 15     daniteur
# 16     diaiteur
# 17    eneliteur
# 18     eniiteur
# 19     ergiteur
# 20     fbkiteur
# 21     fcaiteur
# 22       giteur
# 23      igiteur
# 24     inwiteur
# 25     ispiteur
# 26    juveiteur
# 27     ldoiteur
# 28      mbiteur
# 29    monciteur
# 30      msiteur
# 31     piaiteur
# 32     pryiteur
# 33    raceiteur
# 34     reciteur
# 35    sferiteur
# 36     spmiteur
# 37     srgiteur
# 38     srsiteur
# 39     stmiteur
# 40     teniteur
# 41     tisiteur
# 42     tititeur
# 43     toditeur
# 44     trniteur
# 45     ucgiteur
# 46      usiteur
# 47     wbditeur
# Name: id, dtype: object
# a2aiteur not in list. Adding to list...
# agliteur not in list. Adding to list...
# ampiteur not in list. Adding to list...
# atliteur not in list. Adding to list...
# azmiteur not in list. Adding to list...
# bamiiteur not in list. Adding to list...
# bciteur not in list. Adding to list...
# bmpsiteur not in list. Adding to list...
# bpeiteur not in list. Adding to list...
# breiteur not in list. Adding to list...
# bzuiteur not in list. Adding to list...
# cassiteur not in list. Adding to list...
# cerviteur not in list. Adding to list...
# cpriteur not in list. Adding to list...
# cvaliteur not in list. Adding to list...
# daniteur not in list. Adding to list...
# diaiteur not in list. Adding to list...
# eneliteur not in list. Adding to list...
# eniiteur not in list. Adding to list...
# ergiteur not in list. Adding to list...
# fbkiteur not in list. Adding to list...
# fcaiteur not in list. Adding to list...
# giteur not in list. Adding to list...
# igiteur not in list. Adding to list...
# inwiteur not in list. Adding to list...
# ispiteur not in list. Adding to list...
# juveiteur not in list. Adding to list...
# ldoiteur not in list. Adding to list...
# mbiteur not in list. Adding to list...
# monciteur not in list. Adding to list...
# msiteur not in list. Adding to list...
# piaiteur not in list. Adding to list...
# pryiteur not in list. Adding to list...
# raceiteur not in list. Adding to list...
# reciteur not in list. Adding to list...
# sferiteur not in list. Adding to list...
# spmiteur not in list. Adding to list...
# srgiteur not in list. Adding to list...
# srsiteur not in list. Adding to list...
# stmiteur not in list. Adding to list...
# teniteur not in list. Adding to list...
# tisiteur not in list. Adding to list...
# tititeur not in list. Adding to list...
# toditeur not in list. Adding to list...
# trniteur not in list. Adding to list...
# ucgiteur not in list. Adding to list...
# usiteur not in list. Adding to list...
# wbditeur not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/japan, with id: 0     2502jpjpy
# 1     2503jpjpy
# 2     2914jpjpy
# 3     3382jpjpy
# 4     3436jpjpy
# 5     4004jpjpy
# 6     4005jpjpy
# 7     4063jpjpy
# 8     4452jpjpy
# 9     4502jpjpy
# 10    4503jpjpy
# 11    4507jpjpy
# 12    4523jpjpy
# 13    4543jpjpy
# 14    4689jpjpy
# 15    4911jpjpy
# 16    5108jpjpy
# 17    5301jpjpy
# 18    5401jpjpy
# 19    6098jpjpy
# 20    6301jpjpy
# 21    6367jpjpy
# 22    6501jpjpy
# 23    6502jpjpy
# 24    6503jpjpy
# 25    6506jpjpy
# 26    6702jpjpy
# 27    6752jpjpy
# 28    6758jpjpy
# 29    6762jpjpy
# 30    6902jpjpy
# 31    6954jpjpy
# 32    6971jpjpy
# 33    7201jpjpy
# 34    7203jpjpy
# 35    7261jpjpy
# 36    7267jpjpy
# 37    7269jpjpy
# 38    7270jpjpy
# 39    7751jpjpy
# 40    7974jpjpy
# 41    8031jpjpy
# 42    8035jpjpy
# 43    8306jpjpy
# 44    8316jpjpy
# 45    8411jpjpy
# 46    8766jpjpy
# 47    8801jpjpy
# 48    8802jpjpy
# 49    9020jpjpy
# 50    9432jpjpy
# 51    9433jpjpy
# 52    9501jpjpy
# 53    9983jpjpy
# 54    9984jpjpy
# Name: id, dtype: object
# 2502jpjpy not in list. Adding to list...
# 2503jpjpy not in list. Adding to list...
# 2914jpjpy not in list. Adding to list...
# 3382jpjpy not in list. Adding to list...
# 3436jpjpy not in list. Adding to list...
# 4004jpjpy not in list. Adding to list...
# 4005jpjpy not in list. Adding to list...
# 4063jpjpy not in list. Adding to list...
# 4452jpjpy not in list. Adding to list...
# 4502jpjpy not in list. Adding to list...
# 4503jpjpy not in list. Adding to list...
# 4507jpjpy not in list. Adding to list...
# 4523jpjpy not in list. Adding to list...
# 4543jpjpy not in list. Adding to list...
# 4689jpjpy not in list. Adding to list...
# 4911jpjpy not in list. Adding to list...
# 5108jpjpy not in list. Adding to list...
# 5301jpjpy not in list. Adding to list...
# 5401jpjpy not in list. Adding to list...
# 6098jpjpy not in list. Adding to list...
# 6301jpjpy not in list. Adding to list...
# 6367jpjpy not in list. Adding to list...
# 6501jpjpy not in list. Adding to list...
# 6502jpjpy not in list. Adding to list...
# 6503jpjpy not in list. Adding to list...
# 6506jpjpy not in list. Adding to list...
# 6702jpjpy not in list. Adding to list...
# 6752jpjpy not in list. Adding to list...
# 6758jpjpy not in list. Adding to list...
# 6762jpjpy not in list. Adding to list...
# 6902jpjpy not in list. Adding to list...
# 6954jpjpy not in list. Adding to list...
# 6971jpjpy not in list. Adding to list...
# 7201jpjpy not in list. Adding to list...
# 7203jpjpy not in list. Adding to list...
# 7261jpjpy not in list. Adding to list...
# 7267jpjpy not in list. Adding to list...
# 7269jpjpy not in list. Adding to list...
# 7270jpjpy not in list. Adding to list...
# 7751jpjpy not in list. Adding to list...
# 7974jpjpy not in list. Adding to list...
# 8031jpjpy not in list. Adding to list...
# 8035jpjpy not in list. Adding to list...
# 8306jpjpy not in list. Adding to list...
# 8316jpjpy not in list. Adding to list...
# 8411jpjpy not in list. Adding to list...
# 8766jpjpy not in list. Adding to list...
# 8801jpjpy not in list. Adding to list...
# 8802jpjpy not in list. Adding to list...
# 9020jpjpy not in list. Adding to list...
# 9432jpjpy not in list. Adding to list...
# 9433jpjpy not in list. Adding to list...
# 9501jpjpy not in list. Adding to list...
# 9983jpjpy not in list. Adding to list...
# 9984jpjpy not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/mexico, with id: 0         alfaamxmxn
# 1         alseamxmxn
# 2          amxlmxmxn
# 3          arcamxmxn
# 4         asurbmxmxn
# 5       bbajioomxmxn
# 6        bolsaamxmxn
# 7      cemexcpomxmxn
# 8       elektramxmxn
# 9      femsaubdmxmxn
# 10         gapbmxmxn
# 11     gcarsoa1mxmxn
# 12          gccmxmxn
# 13     gfnorteomxmxn
# 14     gmexicobmxmxn
# 15       grumabmxmxn
# 16      kimberamxmxn
# 17       kofublmxmxn
# 18         labbmxmxn
# 19    livepolc1mxmxn
# 20      megacpomxmxn
# 21         omabmxmxn
# 22        orbiamxmxn
# 23       peolesmxmxn
# 24       pinframxmxn
# 25            qmxmxn
# 26           ramxmxn
# 27       volaramxmxn
# 28       walmexmxmxn
# Name: id, dtype: object
# alfaamxmxn not in list. Adding to list...
# alseamxmxn not in list. Adding to list...
# amxlmxmxn not in list. Adding to list...
# arcamxmxn not in list. Adding to list...
# asurbmxmxn not in list. Adding to list...
# bbajioomxmxn not in list. Adding to list...
# bolsaamxmxn not in list. Adding to list...
# cemexcpomxmxn not in list. Adding to list...
# elektramxmxn not in list. Adding to list...
# femsaubdmxmxn not in list. Adding to list...
# gapbmxmxn not in list. Adding to list...
# gcarsoa1mxmxn not in list. Adding to list...
# gccmxmxn not in list. Adding to list...
# gfnorteomxmxn not in list. Adding to list...
# gmexicobmxmxn not in list. Adding to list...
# grumabmxmxn not in list. Adding to list...
# kimberamxmxn not in list. Adding to list...
# kofublmxmxn not in list. Adding to list...
# labbmxmxn not in list. Adding to list...
# livepolc1mxmxn not in list. Adding to list...
# megacpomxmxn not in list. Adding to list...
# omabmxmxn not in list. Adding to list...
# orbiamxmxn not in list. Adding to list...
# peolesmxmxn not in list. Adding to list...
# pinframxmxn not in list. Adding to list...
# qmxmxn not in list. Adding to list...
# ramxmxn not in list. Adding to list...
# volaramxmxn not in list. Adding to list...
# walmexmxmxn not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/netherlands, with id: 0      agnnleur
# 1       ahnleur
# 2     akzanleur
# 3     asmlnleur
# 4      dsmnleur
# 5     heianleur
# 6     inganleur
# 7      kpnnleur
# 8       mtnleur
# 9     phianleur
# 10     qianleur
# 11    randnleur
# 12    rdsanleur
# 13     rennleur
# 14     unanleur
# 15     vpknleur
# 16     wklnleur
# Name: id, dtype: object
# agnnleur not in list. Adding to list...
# ahnleur not in list. Adding to list...
# akzanleur not in list. Adding to list...
# asmlnleur not in list. Adding to list...
# dsmnleur not in list. Adding to list...
# heianleur not in list. Adding to list...
# inganleur not in list. Adding to list...
# kpnnleur not in list. Adding to list...
# mtnleur not in list. Adding to list...
# phianleur not in list. Adding to list...
# qianleur not in list. Adding to list...
# randnleur not in list. Adding to list...
# rdsanleur not in list. Adding to list...
# rennleur not in list. Adding to list...
# unanleur not in list. Adding to list...
# vpknleur not in list. Adding to list...
# wklnleur not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/norway, with id: 0    dnbnonok
# 1    mhgnonok
# 2    nhynonok
# 3    orknonok
# 4    stlnonok
# 5    telnonok
# Name: id, dtype: object
# dnbnonok not in list. Adding to list...
# mhgnonok not in list. Adding to list...
# nhynonok not in list. Adding to list...
# orknonok not in list. Adding to list...
# stlnonok not in list. Adding to list...
# telnonok not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/portugal, with id: 0     edppteur
# 1    galppteur
# Name: id, dtype: object
# edppteur not in list. Adding to list...
# galppteur not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/spain, with id: 0      acseseur
# 1      acxeseur
# 2     aenaeseur
# 3      amseseur
# 4      appeseur
# 5     bbvaeseur
# 6     cabkeseur
# 7      diaeseur
# 8      ebreseur
# 9      eleeseur
# 10     engeseur
# 11     fcceseur
# 12     fereseur
# 13     gameseur
# 14     gaseseur
# 15     grfeseur
# 16     ibeeseur
# 17     itxeseur
# 18     mapeseur
# 19     reeeseur
# 20     repeseur
# 21     saneseur
# 22     tefeseur
# 23     viseseur
# Name: id, dtype: object
# acseseur not in list. Adding to list...
# acxeseur not in list. Adding to list...
# aenaeseur not in list. Adding to list...
# amseseur not in list. Adding to list...
# appeseur not in list. Adding to list...
# bbvaeseur not in list. Adding to list...
# cabkeseur not in list. Adding to list...
# diaeseur not in list. Adding to list...
# ebreseur not in list. Adding to list...
# eleeseur not in list. Adding to list...
# engeseur not in list. Adding to list...
# fcceseur not in list. Adding to list...
# fereseur not in list. Adding to list...
# gameseur not in list. Adding to list...
# gaseseur not in list. Adding to list...
# grfeseur not in list. Adding to list...
# ibeeseur not in list. Adding to list...
# itxeseur not in list. Adding to list...
# mapeseur not in list. Adding to list...
# reeeseur not in list. Adding to list...
# repeseur not in list. Adding to list...
# saneseur not in list. Adding to list...
# tefeseur not in list. Adding to list...
# viseseur not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/sweden, with id: 0       abbsesek
# 1      alfasesek
# 2     atcoasesek
# 3     eluxbsesek
# 4     ericbsesek
# 5     getibsesek
# 6       hmbsesek
# 7     invebsesek
# 8       ndasesek
# 9      sandsesek
# 10     scabsesek
# 11     sebasesek
# 12    secubsesek
# 13     skabsesek
# 14     skfbsesek
# 15    swedasesek
# 16     swmasesek
# 17    tel2bsesek
# 18     tlsnsesek
# 19    volvbsesek
# Name: id, dtype: object
# abbsesek not in list. Adding to list...
# alfasesek not in list. Adding to list...
# atcoasesek not in list. Adding to list...
# eluxbsesek not in list. Adding to list...
# ericbsesek not in list. Adding to list...
# getibsesek not in list. Adding to list...
# hmbsesek not in list. Adding to list...
# invebsesek not in list. Adding to list...
# ndasesek not in list. Adding to list...
# sandsesek not in list. Adding to list...
# scabsesek not in list. Adding to list...
# sebasesek not in list. Adding to list...
# secubsesek not in list. Adding to list...
# skabsesek not in list. Adding to list...
# skfbsesek not in list. Adding to list...
# swedasesek not in list. Adding to list...
# swmasesek not in list. Adding to list...
# tel2bsesek not in list. Adding to list...
# tlsnsesek not in list. Adding to list...
# volvbsesek not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/switzerland, with id: 0     abbnchchf
# 1     adenchchf
# 2     baerchchf
# 3      cfrchchf
# 4      clnchchf
# 5     csgnchchf
# 6     givnchchf
# 7     kninchchf
# 8      lhnchchf
# 9     lispchchf
# 10    lognchchf
# 11    lonnchchf
# 12    mbtnchchf
# 13    nesnchchf
# 14    novnchchf
# 15    oerlchchf
# 16     rogchchf
# 17    scmnchchf
# 18    sgsnchchf
# 19    slhnchchf
# 20    soonchchf
# 21    srenchchf
# 22    temnchchf
# 23    ubsgchchf
# 24     uhrchchf
# 25    uhrnchchf
# 26    vifnchchf
# 27    zurnchchf
# Name: id, dtype: object
# abbnchchf not in list. Adding to list...
# adenchchf not in list. Adding to list...
# baerchchf not in list. Adding to list...
# cfrchchf not in list. Adding to list...
# clnchchf not in list. Adding to list...
# csgnchchf not in list. Adding to list...
# givnchchf not in list. Adding to list...
# kninchchf not in list. Adding to list...
# lhnchchf not in list. Adding to list...
# lispchchf not in list. Adding to list...
# lognchchf not in list. Adding to list...
# lonnchchf not in list. Adding to list...
# mbtnchchf not in list. Adding to list...
# nesnchchf not in list. Adding to list...
# novnchchf not in list. Adding to list...
# oerlchchf not in list. Adding to list...
# rogchchf not in list. Adding to list...
# scmnchchf not in list. Adding to list...
# sgsnchchf not in list. Adding to list...
# slhnchchf not in list. Adding to list...
# soonchchf not in list. Adding to list...
# srenchchf not in list. Adding to list...
# temnchchf not in list. Adding to list...
# ubsgchchf not in list. Adding to list...
# uhrchchf not in list. Adding to list...
# uhrnchchf not in list. Adding to list...
# vifnchchf not in list. Adding to list...
# zurnchchf not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/uk, with id: 0       aalgbgbx
# 1       abfgbgbx
# 2       admgbgbx
# 3       agkgbgbx
# 4       ahtgbgbx
#          ...
# 97      vodgbgbx
# 98     weirgbgbx
# 99      wosgbgbx
# 100     wppgbgbx
# 101     wtbgbgbx
# Name: id, Length: 102, dtype: object
# aalgbgbx not in list. Adding to list...
# abfgbgbx not in list. Adding to list...
# admgbgbx not in list. Adding to list...
# agkgbgbx not in list. Adding to list...
# ahtgbgbx not in list. Adding to list...
# antogbgbx not in list. Adding to list...
# avgbgbx not in list. Adding to list...
# avvgbgbx not in list. Adding to list...
# azngbgbx not in list. Adding to list...
# bagbgbx not in list. Adding to list...
# babgbgbx not in list. Adding to list...
# barcgbgbx not in list. Adding to list...
# batsgbgbx not in list. Adding to list...
# bdevgbgbx not in list. Adding to list...
# blndgbgbx not in list. Adding to list...
# bltgbgbx not in list. Adding to list...
# bnzlgbgbx not in list. Adding to list...
# bpgbgbx not in list. Adding to list...
# brbygbgbx not in list. Adding to list...
# btgbgbx not in list. Adding to list...
# cclgbgbx not in list. Adding to list...
# cnagbgbx not in list. Adding to list...
# cpggbgbx not in list. Adding to list...
# cpigbgbx not in list. Adding to list...
# crdagbgbx not in list. Adding to list...
# crhgbgbx not in list. Adding to list...
# dccgbgbx not in list. Adding to list...
# dgegbgbx not in list. Adding to list...
# dphgbgbx not in list. Adding to list...
# ecmgbgbx not in list. Adding to list...
# expngbgbx not in list. Adding to list...
# ezjgbgbx not in list. Adding to list...
# fresgbgbx not in list. Adding to list...
# gfsgbgbx not in list. Adding to list...
# glengbgbx not in list. Adding to list...
# gskgbgbx not in list. Adding to list...
# hikgbgbx not in list. Adding to list...
# hlmagbgbx not in list. Adding to list...
# hmsogbgbx not in list. Adding to list...
# hsbagbgbx not in list. Adding to list...
# iaggbgbx not in list. Adding to list...
# icpgbgbx not in list. Adding to list...
# ihggbgbx not in list. Adding to list...
# iiigbgbx not in list. Adding to list...
# imtgbgbx not in list. Adding to list...
# itrkgbgbx not in list. Adding to list...
# itvgbgbx not in list. Adding to list...
# kgfgbgbx not in list. Adding to list...
# landgbgbx not in list. Adding to list...
# lgengbgbx not in list. Adding to list...
# lloygbgbx not in list. Adding to list...
# lsegbgbx not in list. Adding to list...
# mggtgbgbx not in list. Adding to list...
# mksgbgbx not in list. Adding to list...
# mndigbgbx not in list. Adding to list...
# mnggbgbx not in list. Adding to list...
# mrwgbgbx not in list. Adding to list...
# nggbgbx not in list. Adding to list...
# nxtgbgbx not in list. Adding to list...
# ocdogbgbx not in list. Adding to list...
# pfcgbgbx not in list. Adding to list...
# phnxgbgbx not in list. Adding to list...
# prugbgbx not in list. Adding to list...
# psngbgbx not in list. Adding to list...
# psongbgbx not in list. Adding to list...
# rbgbgbx not in list. Adding to list...
# rbsgbgbx not in list. Adding to list...
# rdsbgbgbx not in list. Adding to list...
# relgbgbx not in list. Adding to list...
# riogbgbx not in list. Adding to list...
# rmggbgbx not in list. Adding to list...
# rmvgbgbx not in list. Adding to list...
# rrgbgbx not in list. Adding to list...
# rsagbgbx not in list. Adding to list...
# rtogbgbx not in list. Adding to list...
# sbrygbgbx not in list. Adding to list...
# sdrgbgbx not in list. Adding to list...
# sgegbgbx not in list. Adding to list...
# sgrogbgbx not in list. Adding to list...
# skygbgbx not in list. Adding to list...
# slagbgbx not in list. Adding to list...
# smdsgbgbx not in list. Adding to list...
# smingbgbx not in list. Adding to list...
# smtgbgbx not in list. Adding to list...
# sngbgbx not in list. Adding to list...
# spxgbgbx not in list. Adding to list...
# ssegbgbx not in list. Adding to list...
# stangbgbx not in list. Adding to list...
# stjgbgbx not in list. Adding to list...
# svtgbgbx not in list. Adding to list...
# tategbgbx not in list. Adding to list...
# tlwgbgbx not in list. Adding to list...
# tpkgbgbx not in list. Adding to list...
# tscogbgbx not in list. Adding to list...
# twgbgbx not in list. Adding to list...
# ulvrgbgbx not in list. Adding to list...
# uugbgbx not in list. Adding to list...
# vodgbgbx not in list. Adding to list...
# weirgbgbx not in list. Adding to list...
# wosgbgbx not in list. Adding to list...
# wppgbgbx not in list. Adding to list...
# wtbgbgbx not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/us, with id: 0         aususd
# 1        aaususd
# 2      aabvususd
# 3       aalususd
# 4       aapususd
#          ...
# 603    zbraususd
# 604     zenususd
# 605      zmususd
# 606      zsususd
# 607     ztsususd
# Name: id, Length: 608, dtype: object
# aususd not in list. Adding to list...
# aaususd not in list. Adding to list...
# aabvususd not in list. Adding to list...
# aalususd not in list. Adding to list...
# aapususd not in list. Adding to list...
# aaplususd not in list. Adding to list...
# abcususd not in list. Adding to list...
# abevususd not in list. Adding to list...
# abmdususd not in list. Adding to list...
# abtususd not in list. Adding to list...
# acglususd not in list. Adding to list...
# acmususd not in list. Adding to list...
# acnususd not in list. Adding to list...
# adbeususd not in list. Adding to list...
# adiususd not in list. Adding to list...
# adpususd not in list. Adding to list...
# adskususd not in list. Adding to list...
# aepususd not in list. Adding to list...
# afgususd not in list. Adding to list...
# agncususd not in list. Adding to list...
# aigususd not in list. Adding to list...
# ajgususd not in list. Adding to list...
# albususd not in list. Adding to list...
# algnususd not in list. Adding to list...
# alkususd not in list. Adding to list...
# alksususd not in list. Adding to list...
# allususd not in list. Adding to list...
# alleususd not in list. Adding to list...
# allyususd not in list. Adding to list...
# alnyususd not in list. Adding to list...
# alxnususd not in list. Adding to list...
# amatususd not in list. Adding to list...
# amcrususd not in list. Adding to list...
# amdususd not in list. Adding to list...
# amgnususd not in list. Adding to list...
# amhususd not in list. Adding to list...
# ampususd not in list. Adding to list...
# amtususd not in list. Adding to list...
# amwlususd not in list. Adding to list...
# amznususd not in list. Adding to list...
# anetususd not in list. Adding to list...
# anssususd not in list. Adding to list...
# antmususd not in list. Adding to list...
# aonususd not in list. Adding to list...
# aosususd not in list. Adding to list...
# apaususd not in list. Adding to list...
# apdususd not in list. Adding to list...
# aptvususd not in list. Adding to list...
# arususd not in list. Adding to list...
# areususd not in list. Adding to list...
# armkususd not in list. Adding to list...
# arwususd not in list. Adding to list...
# atoususd not in list. Adding to list...
# atviususd not in list. Adding to list...
# avbususd not in list. Adding to list...
# avgoususd not in list. Adding to list...
# avlrususd not in list. Adding to list...
# avtrususd not in list. Adding to list...
# awkususd not in list. Adding to list...
# axpususd not in list. Adding to list...
# axtaususd not in list. Adding to list...
# ayxususd not in list. Adding to list...
# aznususd not in list. Adding to list...
# azoususd not in list. Adding to list...
# azpnususd not in list. Adding to list...
# baususd not in list. Adding to list...
# babaususd not in list. Adding to list...
# bacususd not in list. Adding to list...
# bahususd not in list. Adding to list...
# bbdususd not in list. Adding to list...
# bbwiususd not in list. Adding to list...
# bbyususd not in list. Adding to list...
# bdxususd not in list. Adding to list...
# beryususd not in list. Adding to list...
# bgususd not in list. Adding to list...
# biduususd not in list. Adding to list...
# biibususd not in list. Adding to list...
# bioususd not in list. Adding to list...
# bkususd not in list. Adding to list...
# bkiususd not in list. Adding to list...
# bkrususd not in list. Adding to list...
# blkususd not in list. Adding to list...
# bmrnususd not in list. Adding to list...
# bmyususd not in list. Adding to list...
# bpususd not in list. Adding to list...
# bpopususd not in list. Adding to list...
# brususd not in list. Adding to list...
# brkbususd not in list. Adding to list...
# brkrususd not in list. Adding to list...
# broususd not in list. Adding to list...
# brxususd not in list. Adding to list...
# bsxususd not in list. Adding to list...
# burlususd not in list. Adding to list...
# bwaususd not in list. Adding to list...
# byndususd not in list. Adding to list...
# cususd not in list. Adding to list...
# caccususd not in list. Adding to list...
# caciususd not in list. Adding to list...
# cagususd not in list. Adding to list...
# cahususd not in list. Adding to list...
# carrususd not in list. Adding to list...
# casyususd not in list. Adding to list...
# catususd not in list. Adding to list...
# cbususd not in list. Adding to list...
# cboeususd not in list. Adding to list...
# cciususd not in list. Adding to list...
# cckususd not in list. Adding to list...
# cclususd not in list. Adding to list...
# cdayususd not in list. Adding to list...
# cdevususd not in list. Adding to list...
# cdkususd not in list. Adding to list...
# cdnsususd not in list. Adding to list...
# cdwususd not in list. Adding to list...
# ceususd not in list. Adding to list...
# cernususd not in list. Adding to list...
# cfususd not in list. Adding to list...
# cfgususd not in list. Adding to list...
# cfrususd not in list. Adding to list...
# cgnxususd not in list. Adding to list...
# chdususd not in list. Adding to list...
# chngususd not in list. Adding to list...
# ciususd not in list. Adding to list...
# clususd not in list. Adding to list...
# clrususd not in list. Adding to list...
# cmcsaususd not in list. Adding to list...
# cmeususd not in list. Adding to list...
# cmgususd not in list. Adding to list...
# cmiususd not in list. Adding to list...
# cncususd not in list. Adding to list...
# cofususd not in list. Adding to list...
# cohrususd not in list. Adding to list...
# coldususd not in list. Adding to list...
# cooususd not in list. Adding to list...
# copususd not in list. Adding to list...
# costususd not in list. Adding to list...
# coupususd not in list. Adding to list...
# cpriususd not in list. Adding to list...
# cprtususd not in list. Adding to list...
# cptususd not in list. Adding to list...
# crlususd not in list. Adding to list...
# crmususd not in list. Adding to list...
# csususd not in list. Adding to list...
# cscoususd not in list. Adding to list...
# csgpususd not in list. Adding to list...
# cslususd not in list. Adding to list...
# csxususd not in list. Adding to list...
# ctlususd not in list. Adding to list...
# ctltususd not in list. Adding to list...
# ctshususd not in list. Adding to list...
# ctvaususd not in list. Adding to list...
# ctxsususd not in list. Adding to list...
# cubeususd not in list. Adding to list...
# cvnaususd not in list. Adding to list...
# cvsususd not in list. Adding to list...
# cvxususd not in list. Adding to list...
# czrususd not in list. Adding to list...
# dususd not in list. Adding to list...
# dalususd not in list. Adding to list...
# dbxususd not in list. Adding to list...
# deususd not in list. Adding to list...
# dellususd not in list. Adding to list...
# dfsususd not in list. Adding to list...
# dgususd not in list. Adding to list...
# dhiususd not in list. Adding to list...
# dhrususd not in list. Adding to list...
# disususd not in list. Adding to list...
# dksususd not in list. Adding to list...
# dlrususd not in list. Adding to list...
# dltrususd not in list. Adding to list...
# docuususd not in list. Adding to list...
# doxususd not in list. Adding to list...
# dpzususd not in list. Adding to list...
# dreususd not in list. Adding to list...
# dtususd not in list. Adding to list...
# dukususd not in list. Adding to list...
# dvaususd not in list. Adding to list...
# dvnususd not in list. Adding to list...
# dxcususd not in list. Adding to list...
# dxcmususd not in list. Adding to list...
# eaususd not in list. Adding to list...
# ebayususd not in list. Adding to list...
# eeftususd not in list. Adding to list...
# efxususd not in list. Adding to list...
# ehcususd not in list. Adding to list...
# eixususd not in list. Adding to list...
# elususd not in list. Adding to list...
# elanususd not in list. Adding to list...
# elsususd not in list. Adding to list...
# emrususd not in list. Adding to list...
# enphususd not in list. Adding to list...
# entgususd not in list. Adding to list...
# eogususd not in list. Adding to list...
# epamususd not in list. Adding to list...
# eqhususd not in list. Adding to list...
# eqtususd not in list. Adding to list...
# esususd not in list. Adding to list...
# essususd not in list. Adding to list...
# estcususd not in list. Adding to list...
# etnususd not in list. Adding to list...
# etsyususd not in list. Adding to list...
# evrgususd not in list. Adding to list...
# ewususd not in list. Adding to list...
# ewbcususd not in list. Adding to list...
# excususd not in list. Adding to list...
# exelususd not in list. Adding to list...
# expeususd not in list. Adding to list...
# exrususd not in list. Adding to list...
# fususd not in list. Adding to list...
# fangususd not in list. Adding to list...
# fbususd not in list. Adding to list...
# fbhsususd not in list. Adding to list...
# fcncaususd not in list. Adding to list...
# fcxususd not in list. Adding to list...
# fdsususd not in list. Adding to list...
# fdxususd not in list. Adding to list...
# feususd not in list. Adding to list...
# ficoususd not in list. Adding to list...
# fitbususd not in list. Adding to list...
# fiveususd not in list. Adding to list...
# flususd not in list. Adding to list...
# fltususd not in list. Adding to list...
# fndususd not in list. Adding to list...
# fnfususd not in list. Adding to list...
# foxaususd not in list. Adding to list...
# frcususd not in list. Adding to list...
# ftiususd not in list. Adding to list...
# ftntususd not in list. Adding to list...
# ftvususd not in list. Adding to list...
# gususd not in list. Adding to list...
# gdususd not in list. Adding to list...
# gddyususd not in list. Adding to list...
# geususd not in list. Adding to list...
# gggususd not in list. Adding to list...
# ghususd not in list. Adding to list...
# gildususd not in list. Adding to list...
# gisususd not in list. Adding to list...
# glususd not in list. Adding to list...
# glpiususd not in list. Adding to list...
# glwususd not in list. Adding to list...
# gmususd not in list. Adding to list...
# gnrcususd not in list. Adding to list...
# googususd not in list. Adding to list...
# googlususd not in list. Adding to list...
# gpnususd not in list. Adding to list...
# gpsususd not in list. Adding to list...
# gsususd not in list. Adding to list...
# gwwususd not in list. Adding to list...
# hususd not in list. Adding to list...
# halususd not in list. Adding to list...
# hbiususd not in list. Adding to list...
# hcaususd not in list. Adding to list...
# hcnususd not in list. Adding to list...
# hdususd not in list. Adding to list...
# heiususd not in list. Adding to list...
# hesususd not in list. Adding to list...
# hiiususd not in list. Adding to list...
# hltususd not in list. Adding to list...
# hogususd not in list. Adding to list...
# honususd not in list. Adding to list...
# hpeususd not in list. Adding to list...
# hpqususd not in list. Adding to list...
# htaususd not in list. Adding to list...
# hubbususd not in list. Adding to list...
# hubsususd not in list. Adding to list...
# humususd not in list. Adding to list...
# hwmususd not in list. Adding to list...
# hznpususd not in list. Adding to list...
# ibkrususd not in list. Adding to list...
# ibmususd not in list. Adding to list...
# iceususd not in list. Adding to list...
# idxxususd not in list. Adding to list...
# iexususd not in list. Adding to list...
# ilmnususd not in list. Adding to list...
# incyususd not in list. Adding to list...
# intcususd not in list. Adding to list...
# intuususd not in list. Adding to list...
# invhususd not in list. Adding to list...
# ionsususd not in list. Adding to list...
# ipgususd not in list. Adding to list...
# ipgpususd not in list. Adding to list...
# iqvususd not in list. Adding to list...
# irususd not in list. Adding to list...
# isrgususd not in list. Adding to list...
# itususd not in list. Adding to list...
# itubususd not in list. Adding to list...
# itwususd not in list. Adding to list...
# ivzususd not in list. Adding to list...
# jazzususd not in list. Adding to list...
# jbluususd not in list. Adding to list...
# jciususd not in list. Adding to list...
# jefususd not in list. Adding to list...
# jkhyususd not in list. Adding to list...
# jllususd not in list. Adding to list...
# jnjususd not in list. Adding to list...
# jpmususd not in list. Adding to list...
# jwnususd not in list. Adding to list...
# kususd not in list. Adding to list...
# keyususd not in list. Adding to list...
# keysususd not in list. Adding to list...
# khcususd not in list. Adding to list...
# kmbususd not in list. Adding to list...
# kmiususd not in list. Adding to list...
# kmxususd not in list. Adding to list...
# knxususd not in list. Adding to list...
# koususd not in list. Adding to list...
# krususd not in list. Adding to list...
# krcususd not in list. Adding to list...
# kssususd not in list. Adding to list...
# lususd not in list. Adding to list...
# lamrususd not in list. Adding to list...
# ldosususd not in list. Adding to list...
# leaususd not in list. Adding to list...
# lenususd not in list. Adding to list...
# lhxususd not in list. Adding to list...
# lkqususd not in list. Adding to list...
# llyususd not in list. Adding to list...
# lmtususd not in list. Adding to list...
# lncususd not in list. Adding to list...
# lngususd not in list. Adding to list...
# lntususd not in list. Adding to list...
# lowususd not in list. Adding to list...
# lplaususd not in list. Adding to list...
# lrcxususd not in list. Adding to list...
# lsiususd not in list. Adding to list...
# lstrususd not in list. Adding to list...
# luluususd not in list. Adding to list...
# luvususd not in list. Adding to list...
# lvsususd not in list. Adding to list...
# lwususd not in list. Adding to list...
# lybususd not in list. Adding to list...
# lyftususd not in list. Adding to list...
# lyvususd not in list. Adding to list...
# mususd not in list. Adding to list...
# maususd not in list. Adding to list...
# maaususd not in list. Adding to list...
# manhususd not in list. Adding to list...
# marususd not in list. Adding to list...
# masiususd not in list. Adding to list...
# matususd not in list. Adding to list...
# mcdususd not in list. Adding to list...
# mchpususd not in list. Adding to list...
# mckususd not in list. Adding to list...
# mdbususd not in list. Adding to list...
# mdlzususd not in list. Adding to list...
# mdtususd not in list. Adding to list...
# metususd not in list. Adding to list...
# mgmususd not in list. Adding to list...
# mhkususd not in list. Adding to list...
# middususd not in list. Adding to list...
# mklususd not in list. Adding to list...
# mksiususd not in list. Adding to list...
# mktxususd not in list. Adding to list...
# mlmususd not in list. Adding to list...
# mmmususd not in list. Adding to list...
# mndtususd not in list. Adding to list...
# ...
# ztsususd not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/bnd_cfd, with id: 0       bundtreur
# 1     ukgilttrgbp
# 2    ustbondtrusd
# Name: id, dtype: object
# bundtreur not in list. Adding to list...
# ukgilttrgbp not in list. Adding to list...
# ustbondtrusd not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/etf_cfd_de, with id: 0    tecdaxedeeur
# Name: id, dtype: object
# tecdaxedeeur not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/etf_cfd_fr, with id: 0       dsbfreur
# 1       lvcfreur
# 2    lyxbnkfreur
# Name: id, dtype: object
# dsbfreur not in list. Adding to list...
# lvcfreur not in list. Adding to list...
# lyxbnkfreur not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/etf_cfd_hk, with id: 0    2822hkhkd
# 1    2828hkhkd
# 2    2836hkhkd
# 3    3188hkhkd
# Name: id, dtype: object
# 2822hkhkd not in list. Adding to list...
# 2828hkhkd not in list. Adding to list...
# 2836hkhkd not in list. Adding to list...
# 3188hkhkd not in list. Adding to list...
# Reading from: https://www.dukascopy-node.app/instruments/etf_cfd_us, with id: 0      diaususd
# 1      dvyususd
# 2      eemususd
# 3      efaususd
# 4      embususd
# 5      ewhususd
# 6      ewjususd
# 7      ewwususd
# 8      ewzususd
# 9      ezuususd
# 10     fxiususd
# 11     gdxususd
# 12    gdxjususd
# 13     gldususd
# 14     ibbususd
# 15     iefususd
# 16     ijhususd
# 17     ijrususd
# 18     iveususd
# 19     ivwususd
# 20     iwdususd
# 21     iwfususd
# 22     iwmususd
# 23     iyrususd
# 24     jnkususd
# 25     qqqususd
# 26     slvususd
# 27     spyususd
# 28     tltususd
# 29     usoususd
# 30     veaususd
# 31     vgkususd
# 32     vnqususd
# 33     vxxususd
# 34     xleususd
# 35     xlfususd
# 36     xliususd
# 37     xlkususd
# 38     xlpususd
# 39     xluususd
# 40     xlvususd
# 41     xlyususd
# 42     xopususd
# Name: id, dtype: object
# diaususd not in list. Adding to list...
# dvyususd not in list. Adding to list...
# eemususd not in list. Adding to list...
# efaususd not in list. Adding to list...
# embususd not in list. Adding to list...
# ewhususd not in list. Adding to list...
# ewjususd not in list. Adding to list...
# ewwususd not in list. Adding to list...
# ewzususd not in list. Adding to list...
# ezuususd not in list. Adding to list...
# fxiususd not in list. Adding to list...
# gdxususd not in list. Adding to list...
# gdxjususd not in list. Adding to list...
# gldususd not in list. Adding to list...
# ibbususd not in list. Adding to list...
# iefususd not in list. Adding to list...
# ijhususd not in list. Adding to list...
# ijrususd not in list. Adding to list...
# iveususd not in list. Adding to list...
# ivwususd not in list. Adding to list...
# iwdususd not in list. Adding to list...
# iwfususd not in list. Adding to list...
# iwmususd not in list. Adding to list...
# iyrususd not in list. Adding to list...
# jnkususd not in list. Adding to list...
# qqqususd not in list. Adding to list...
# slvususd not in list. Adding to list...
# spyususd not in list. Adding to list...
# tltususd not in list. Adding to list...
# usoususd not in list. Adding to list...
# veaususd not in list. Adding to list...
# vgkususd not in list. Adding to list...
# vnqususd not in list. Adding to list...
# vxxususd not in list. Adding to list...
# xleususd not in list. Adding to list...
# xlfususd not in list. Adding to list...
# xliususd not in list. Adding to list...
# xlkususd not in list. Adding to list...
# xlpususd not in list. Adding to list...
# xluususd not in list. Adding to list...
# xlvususd not in list. Adding to list...
# xlyususd not in list. Adding to list...
# xopususd not in list. Adding to list...
# Starting...
# Reading from: https://www.dukascopy-node.app/instruments/fx_crosses, with id: 0     audcad
# 1     audchf
# 2     audjpy
# 3     audnzd
# 4     audsgd
# 5     cadchf
# 6     cadhkd
# 7     cadjpy
# 8     chfjpy
# 9     chfsgd
# 10    euraud
# 11    eurcad
# 12    eurchf
# 13    eurczk
# 14    eurdkk
# 15    eurgbp
# 16    eurhkd
# 17    eurhuf
# 18    eurjpy
# 19    eurnok
# 20    eurnzd
# 21    eurpln
# 22    eursek
# 23    eursgd
# 24    eurtry
# 25    gbpaud
# 26    gbpcad
# 27    gbpchf
# 28    gbpjpy
# 29    gbpnzd
# 30    hkdjpy
# 31    nzdcad
# 32    nzdchf
# 33    nzdjpy
# 34    sgdjpy
# 35    tryjpy
# 36    usdcnh
# 37    usdczk
# 38    usddkk
# 39    usdhkd
# 40    usdhuf
# 41    usdils
# 42    usdmxn
# 43    usdnok
# 44    usdpln
# 45    usdron
# 46    usdsek
# 47    usdsgd
# 48    usdthb
# 49    usdtry
# 50    usdzar
# 51    zarjpy
# Name: id, dtype: object
# Reading from: https://www.dukascopy-node.app/instruments/fx_majors, with id: 0    audusd
# 1    eurusd
# 2    gbpusd
# 3    nzdusd
# 4    usdcad
# 5    usdchf
# 6    usdjpy
# Name: id, dtype: object
# Reading from: https://www.dukascopy-node.app/instruments/fx_metals, with id: 0    xagusd
# 1    xauusd
# Name: id, dtype: object
# Reading from: https://www.dukascopy-node.app/instruments/cmd_agricultural, with id: 0      cocoacmdusd
# 1     coffeecmdusx
# 2     cottoncmdusx
# 3     ojuicecmdusx
# 4    soybeancmdusx
# 5      sugarcmdusd
# Name: id, dtype: object
# Reading from: https://www.dukascopy-node.app/instruments/cmd_energy, with id: 0    dieselcmdusd
# 1     brentcmdusd
# 2     lightcmdusd
# 3       gascmdusd
# Name: id, dtype: object
# Reading from: https://www.dukascopy-node.app/instruments/cmd_metals, with id: 0    coppercmdusd
# 1       xpdcmdusd
# 2       xptcmdusd
# Name: id, dtype: object
# Reading from: https://www.dukascopy-node.app/instruments/idx_america, with id: 0      dollaridxusd
# 1       usa30idxusd
# 2     usatechidxusd
# 3      usa500idxusd
# 4    ussc2000idxusd
# 5         volidxusd
# Name: id, dtype: object
# Reading from: https://www.dukascopy-node.app/instruments/idx_asia, with id: 0    chiidxusd
# 1    hkgidxhkd
# 2    jpnidxjpy
# 3    ausidxaud
# 4    indidxusd
# 5    sgdidxsgd
# Name: id, dtype: object
# Reading from: https://www.dukascopy-node.app/instruments/idx_europe, with id: 0    fraidxeur
# 1    deuidxeur
# 2    eusidxeur
# 3    gbridxgbp
# 4    espidxeur
# 5    cheidxchf
# 6    nldidxeur
# 7    plnidxpln
# Name: id, dtype: object
# Reading from: https://www.dukascopy-node.app/instruments/idx_africa, with id: 0    soaidxzar
# Name: id, dtype: object
# Reading from: https://www.dukascopy-node.app/instruments/austria, with id: 0    ebsateur
# 1    rbiateur
# 2    voeateur
# Name: id, dtype: object
# Reading from: https://www.dukascopy-node.app/instruments/belgium, with id: 0     abibeeur
# 1     agsbeeur
# 2    belgbeeur
# 3     kbcbeeur
# 4    solbbeeur
# 5     ucbbeeur
# 6     umibeeur
# Name: id, dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 interval = 1
# ----> 2 periodic_work(interval, list_urls, symb_list)
#
# Input In [12], in periodic_work(interval, list_urls, symb_list)
#      59 for url in list_urls:
#      60     print(f"Reading from: {url}, with id: {pd.read_html(url)[0]['id']}")
# ---> 61     table_id = pd.read_html(url)[0]['id']
#      62     for symbol in table_id:
#      63         if symbol not in symb_list:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1201 validate_header_arg(header)
#    1203 io = stringify_path(io)
# -> 1205 return _parse(
#    1206     flavor=flavor,
#    1207     io=io,
#    1208     match=match,
#    1209     header=header,
#    1210     index_col=index_col,
#    1211     skiprows=skiprows,
#    1212     parse_dates=parse_dates,
#    1213     thousands=thousands,
#    1214     attrs=attrs,
#    1215     encoding=encoding,
#    1216     decimal=decimal,
#    1217     converters=converters,
#    1218     na_values=na_values,
#    1219     keep_default_na=keep_default_na,
#    1220     displayed_only=displayed_only,
#    1221     extract_links=extract_links,
#    1222 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\html.py:986, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     983 p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#     985 try:
# --> 986     tables = p.parse_tables()
#     987 except ValueError as caught:
#     988     # if `io` is an io-like object, check if it's seekable
#     989     # and try to rewind it before trying the next parser
#     990     if hasattr(io, "seekable") and io.seekable():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\html.py:262, in _HtmlFrameParser.parse_tables(self)
#     254 def parse_tables(self):
#     255     """
#     256     Parse and return all tables from the DOM.
#     257
#    (...)
#     260     list of parsed (header, body, footer) tuples from tables.
#     261     """
# --> 262     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     263     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\html.py:802, in _LxmlFrameParser._build_doc(self)
#     800 try:
#     801     if is_url(self.io):
# --> 802         with urlopen(self.io) as f:
#     803             r = parse(f, parser=parser)
#     804     else:
#     805         # try to parse the input in the simplest way
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\common.py:266, in urlopen(*args, **kwargs)
#     260 """
#     261 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     262 the stdlib.
#     263 """
#     264 import urllib.request
# --> 266 return urllib.request.urlopen(*args, **kwargs)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346 try:
#    1347     try:
# -> 1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1279 def request(self, method, url, body=None, headers={}, *,
#    1280             encode_chunked=False):
#    1281     """Send a complete request to the server."""
# -> 1282     self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1324 if isinstance(body, str):
#    1325     # RFC 2616 Section 3.7.1 says that text default has a
#    1326     # default charset of iso-8859-1.
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1275 else:
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1035 msg = b"\r\n".join(self._buffer)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#    1042     if hasattr(message_body, 'read'):
#    1043         # Let file-like take precedence over byte-like.  This
#    1044         # is needed to allow the current position of mmap'ed
#    1045         # files to be taken into account.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:975, in HTTPConnection.send(self, data)
#     973 if self.sock is None:
#     974     if self.auto_open:
# --> 975         self.connect()
#     976     else:
#     977         raise NotConnected()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:1447, in HTTPSConnection.connect(self)
#    1444 def connect(self):
#    1445     "Connect to a host on a given (SSL) port."
# -> 1447     super().connect()
#    1449     if self._tunnel_host:
#    1450         server_hostname = self._tunnel_host
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:941, in HTTPConnection.connect(self)
#     939 """Connect to the host and port specified in __init__."""
#     940 sys.audit("http.client.connect", self, self.host, self.port)
# --> 941 self.sock = self._create_connection(
#     942     (self.host,self.port), self.timeout, self.source_address)
#     943 # Might fail in OSs that don't implement TCP_NODELAY
#     944 try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\socket.py:833, in create_connection(address, timeout, source_address)
#     831 if source_address:
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
#     834 # Break explicitly a reference cycle
#     835 err = None
#
# KeyboardInterrupt:

# %%
print(symb_list)
# Out:
# []

# %%
len(symb_list)
# Out:
# 1230

# %%
df = pd.DataFrame(symb_list)
df

# %%
output = 'C:/Users/hello/Documents/GitHub/eq-sys-1/symbol_list.txt'
df.to_csv(output, index=False, sep='\n')

# %%
# Convert .ipynb to py for task scheduler
# jupyter nbconvert --to script notebook.ipynb

# %%
# Read csv to .db
#         duka_us.to_sql("Main" ,engine, if_exists='fail')

# %%
# wiki = 'https://en.wikipedia.org/wiki/'
# tickersSPY = pd.read_html(wiki + 'List_of_S%26P_500_companies')[0]['Symbol'].to_list()
# len(tickersSPY)

# %%
# import os

# # Print the environment variables
# print("Environment variables:")
# for key, value in os.environ.items():
#     print(f"{key}: {value}")

# # Print the PATH variable
# print("\nPATH variable:")
# print(os.environ["PATH"])

# %%
# periodic_work(300)
